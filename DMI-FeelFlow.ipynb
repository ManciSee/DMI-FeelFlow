# %%
# Out:
# /home/melo/.local/lib/python3.11/site-packages/pyrogram/methods/utilities/run.py:84: RuntimeWarning: coroutine 'Start.start' was never awaited
#   self.start()
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/melo/Desktop/Git/DMI-FeelFlow/DMI-FeelFlow.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/home/melo/Desktop/Git/DMI-FeelFlow/DMI-FeelFlow.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> # Create a Pyrogram client
#      <a href='vscode-notebook-cell:/home/melo/Desktop/Git/DMI-FeelFlow/DMI-FeelFlow.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> app = Client('session_name', api_id=api_id, api_hash=api_hash)
# ---> <a href='vscode-notebook-cell:/home/melo/Desktop/Git/DMI-FeelFlow/DMI-FeelFlow.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> app.run()
# ...
